# %%
import pandas as pd

# %%
amazon=pd.read_csv(r"C:\Users\Pablo\Desktop\Practica\labs PI 1\PI01_DATA05\Datasets\amazon_prime_titles.csv", sep=",")

# %%
amazon.drop_duplicates(inplace=True)

# %%
amazon.duration.replace("min","",inplace=True,regex=True)
amazon.duration.replace("Season","",inplace=True,regex=True)
amazon.duration.replace("Seasons","",inplace=True,regex=True)
amazon.duration.replace("s","",inplace=True,regex=True)

# %%
amazon.duration=amazon.duration.astype(int)

# %%
amazon.durationseason.sort_values(ascending=False)
# Out:
# 1078    29
# 3032    29
# 6178    29
# 4158    29
# 770     29
#         ..
# 4103     0
# 4102     0
# 4101     0
# 4100     0
# 9667     0
# Name: durationseason, Length: 9668, dtype: int64

# %%
amazon.listed_in.replace(" ","",inplace=True,regex=True)

# %%
amazon.listed_in
# Out:
# 0                Comedy,Drama
# 1         Drama,International
# 2       Action,Drama,Suspense
# 3                 Documentary
# 4               Drama,Fantasy
#                 ...
# 9663                   Comedy
# 9664                  TVShows
# 9665                   Action
# 9666             Drama,Sports
# 9667    Action,Drama,Suspense
# Name: listed_in, Length: 9668, dtype: object

# %%
movie=amazon[(amazon["type"]=="Movie")].duration.max()
movie
# Out:
# 601

# %%
serie=amazon[(amazon["type"]=="TV Show")].duration.max()
serie
# Out:
# 29

# %%
#y=0
#x=amazon[(amazon["type"]=="Movie")].duration.max()
#for indice, elemento in enumerate(amazon["duration"]): 
#    if amazon["duration"][indice].max()==x : 
#        y+=amazon["release_year"][indice]
#print("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)
# Out:
# La peli de Amazon con mayor duracion tiene: 601 minutos, año: 2018

# %%
df1=amazon[(amazon["release_year"]==2018)].durationseason.max()
df1
# Out:
# 25

# %%
amazon[(amazon["release_year"]==2018)].durationseason
# Out:
# 1       0
# 12      0
# 14      0
# 19      0
# 29      3
#        ..
# 9563    0
# 9596    0
# 9632    1
# 9639    0
# 9664    4
# Name: durationseason, Length: 623, dtype: int64

# %%
df=amazon[(amazon["release_year"]==int(2018))].durationmovie.max()
df
# Out:
# 601

# %%
def get_max_duration1(año,plataforma,min):
    a=int(año)
    p=str(plataforma)
    q=str(min)
    y=[]
    df=amazon[(amazon["release_year"]==int(a))].durationmovie.max()
    df1=amazon[(amazon["release_year"]==int(a))].durationseason.max()
    df2=disney[(disney["release_year"]==int(a))].durationmovie.max()
    df3=disney[(disney["release_year"]==int(a))].durationseason.max()
    df4=hulu[(hulu["release_year"]==int(a))].durationmovie.max()
    df5=hulu[(hulu["release_year"]==int(a))].durationseason.max()
    df6=netflix[(netflix["release_year"]==int(a))].durationmovie.max()
    df7=netflix[(netflix["release_year"]==int(a))].durationseason.max()
    
    if q=="min" and p=="Amazon":
        for indice, elemento in enumerate(amazon["durationmovie"]): 
            if amazon["durationmovie"][indice].max()==df and amazon["release_year"][indice]==a:
                y.append(amazon["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)
    
    if q=="season" and p=="Amazon":
        for indice, elemento in enumerate(amazon["durationseason"]): 
            if amazon["durationseason"][indice].max()==df1 and amazon["release_year"][indice]==a:
                y.append(amazon["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)

    if q=="min" and p=="Disney":
        for indice, elemento in enumerate(disney["durationmovie"]): 
            if disney["durationmovie"][indice].max()==df2 and disney["release_year"][indice]==a:
                y.append(disney["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)
    
    if q=="season" and p=="Disney":
        for indice, elemento in enumerate(disney["durationseason"]): 
            if disney["durationseason"][indice].max()==df3 and disney["release_year"][indice]==a:
                y.append(disney["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)

    if q=="min" and p=="Hulu":
        for indice, elemento in enumerate(hulu["durationmovie"]): 
            if hulu["durationmovie"][indice].max()==df4 and hulu["release_year"][indice]==a:
                y.append(hulu["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)
    
    if q=="season" and p=="Hulu":
        for indice, elemento in enumerate(hulu["durationseason"]): 
            if hulu["durationseason"][indice].max()==df5 and hulu["release_year"][indice]==a:
                y.append(hulu["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)

    if q=="min" and p=="Netflix":
        for indice, elemento in enumerate(netflix["durationmovie"]): 
            if netflix["durationmovie"][indice].max()==df6 and netflix["release_year"][indice]==a:
                y.append(netflix["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)
    
    if q=="season" and p=="Netflix":
        for indice, elemento in enumerate(netflix["durationseason"]): 
            if netflix["durationseason"][indice].max()==df7 and netflix["release_year"][indice]==a:
                y.append(netflix["title"][indice])
        return y #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)

# %%
get_max_duration1(2020,"Netflix","min")
# Out:
# ['Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend']

# %%
def get_max_duration(año,plataforma,minu):
    a=int(año)
    p=plataforma
    Movie=minu
    y=[]
    
    df=amazon[(amazon["release_year"]==int(a))].duration.max()
    
    
    for indice, elemento in enumerate(amazon["duration"]): 
        if amazon["duration"][indice].max()==df and amazon["release_year"][indice]==a:
            y.append(amazon["title"][indice])
    print(y) #("La peli de Amazon con mayor duracion tiene:",x,"minutos, año:",y)

# %%
get_max_duration(2017,"Amazon",1)
# Out:
# ['Himalayan Singing Bowls 9 hours']

# %%
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating  duration              listed_in  \
# 0  March 30, 2021          2014    NaN       113           Comedy,Drama
# 1  March 30, 2021          2018    13+       110    Drama,International
# 2  March 30, 2021          2017    NaN        74  Action,Drama,Suspense
# 3  March 30, 2021          2014    NaN        69            Documentary
# 4  March 30, 2021          1989    NaN        45          Drama,Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %%
def get_count_plataform(plataforma):
    if plataforma=="amazon":
        cantseries=len(amazon[(amazon["type"]=="TV Show")].count(axis=1))
        cantmovie=len(amazon[(amazon["type"]=="Movie")].count(axis=1))
        return "La plataforma Amazon tiene un total de:",cantseries,"series y un total de:",cantmovie,"movies"

    if plataforma=="disney":
        cantseries=len(disney[(disney["type"]=="TV Show")].count(axis=1))
        cantmovie=len(disney[(disney["type"]=="Movie")].count(axis=1))
        return "La plataforma Disney tiene un total de:",cantseries,"series y un total de:",cantmovie,"movies"
    
    if plataforma=="hulu":
        cantseries=len(hulu[(hulu["type"]=="TV Show")].count(axis=1))
        cantmovie=len(hulu[(hulu["type"]=="Movie")].count(axis=1))
        return "La plataforma Hulu tiene un total de:",cantseries,"series y un total de:",cantmovie,"movies"
        
    if plataforma=="netflix":
        cantseries=len(netflix[(netflix["type"]=="TV Show")].count(axis=1))
        cantmovie=len(netflix[(netflix["type"]=="Movie")].count(axis=1))
        return "La plataforma Netflix tiene un total de:",cantseries,"series y un total de:",cantmovie,"movies"

# %%
get_count_plataform("netflix")
# Out:
# ('La plataforma Netflix tiene un total de:',
#  2676,
#  'series y un total de:',
#  6131,
#  'movies')

# %%
cantmovie=len(amazon[(amazon["type"]=="Movie")].count(axis=1))
print("La plataforma Amazon tiene un total de:",cantmovie,"peliculas")
# Out:
# La plataforma Amazon tiene un total de: 7814 peliculas

# %%
cantseries=len(amazon[(amazon["type"]=="TV Show")].count(axis=1))
print("La plataforma Amazon tiene un total de:",cantseries,"series")
# Out:
# La plataforma Amazon tiene un total de: 1854 series

# %%
generos=amazon['listed_in'].tolist()
r=[]
for i in generos:
    r.append(i.split(","))
r
# Out:
# [['Comedy', 'Drama'],
#  ['Drama', 'International'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Documentary'],
#  ['Drama', 'Fantasy'],
#  ['Fantasy', 'Kids'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy'],
#  ['Action', 'ScienceFiction', 'Suspense'],
#  ['Drama'],
#  ['Adventure', 'Kids'],
#  ['Comedy'],
#  ['Horror', 'Suspense'],
#  ['Documentary', 'Sports'],
#  ['Documentary'],
#  ['Comedy', 'Drama'],
#  ['Horror', 'ScienceFiction'],
#  ['Kids', 'SpecialInterest'],
#  ['Comedy', 'TalkShowandVariety'],
#  ['ScienceFiction'],
#  ['Kids'],
#  ['Action', 'Anime', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Drama'],
#  ['TVShows'],
#  ['Drama'],
#  ['Documentary'],
#  ['TVShows'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Anime', 'Fantasy'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Anime', 'Kids'],
#  ['TVShows'],
#  ['Drama'],
#  ['MusicVideosandConcerts'],
#  ['MusicVideosandConcerts'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Fitness', 'SpecialInterest'],
#  ['FaithandSpirituality', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Fitness'],
#  ['Fitness', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['Fitness', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Action', 'MilitaryandWar', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'TalkShowandVariety'],
#  ['Drama', 'International'],
#  ['Drama', 'International'],
#  ['Action', 'Western'],
#  ['Documentary', 'ScienceFiction'],
#  ['Adventure', 'Animation', 'Kids'],
#  ['Fantasy', 'ScienceFiction', 'Suspense'],
#  ['Suspense'],
#  ['Action'],
#  ['Documentary', 'LGBTQ'],
#  ['Drama', 'Romance', 'Suspense'],
#  ['Comedy', 'SpecialInterest', 'Unscripted'],
#  ['TVShows'],
#  ['Unscripted'],
#  ['Drama'],
#  ['Documentary'],
#  ['Documentary', 'MilitaryandWar'],
#  ['MusicVideosandConcerts'],
#  ['TVShows'],
#  ['Kids'],
#  ['Drama'],
#  ['Kids'],
#  ['Documentary', 'SpecialInterest'],
#  ['Kids'],
#  ['Kids'],
#  ['Animation', 'Kids'],
#  ['Action', 'Drama'],
#  ['Drama', 'Suspense'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama'],
#  ['Kids'],
#  ['TVShows'],
#  ['Comedy', 'Documentary', 'Unscripted'],
#  ['Comedy', 'Documentary', 'Unscripted'],
#  ['Action', 'Drama'],
#  ['Western'],
#  ['Action', 'Drama', 'Sports'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Documentary', 'International', 'SpecialInterest'],
#  ['Action', 'Drama'],
#  ['Action', 'Drama'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy', 'ScienceFiction'],
#  ['Documentary', 'SpecialInterest'],
#  ['Kids'],
#  ['Action'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama', 'Western'],
#  ['Documentary'],
#  ['TVShows'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Drama', 'SpecialInterest'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Drama', 'Suspense'],
#  ['Action', 'ScienceFiction'],
#  ['Documentary', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Drama'],
#  ['Drama'],
#  ['Action', 'Drama', 'SpecialInterest'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Drama', 'YoungAdultAudience'],
#  ['Drama', 'MilitaryandWar'],
#  ['Drama'],
#  ['Arthouse', 'Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Documentary', 'Kids', 'SpecialInterest'],
#  ['Unscripted'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy'],
#  ['Suspense'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Sports'],
#  ['MilitaryandWar', 'Western'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Kids'],
#  ['Kids'],
#  ['Anime'],
#  ['TVShows'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy', 'International'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Horror', 'Suspense'],
#  ['Drama'],
#  ['Comedy'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary'],
#  ['TVShows'],
#  ['Kids'],
#  ['Comedy'],
#  ['Documentary', 'SpecialInterest'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Action', 'Drama', 'Suspense'],
#  ['SpecialInterest'],
#  ['Comedy', 'Drama'],
#  ['Animation', 'Comedy', 'Kids'],
#  ['Animation', 'Comedy', 'Kids'],
#  ['Action', 'Suspense'],
#  ['Western'],
#  ['Action', 'Drama'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Romance', 'Suspense'],
#  ['Documentary', 'Sports'],
#  ['Action', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary'],
#  ['Documentary', 'Drama', 'Unscripted'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['ScienceFiction'],
#  ['Drama', 'Suspense'],
#  ['Action', 'ScienceFiction', 'Suspense'],
#  ['Drama', 'Suspense'],
#  ['TVShows'],
#  ['Kids'],
#  ['Action', 'Drama', 'International'],
#  ['Drama'],
#  ['Drama', 'ScienceFiction', 'Suspense'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Anime'],
#  ['International', 'Suspense'],
#  ['Action', 'Drama'],
#  ['Documentary', 'International', 'SpecialInterest'],
#  ['TVShows'],
#  ['Documentary'],
#  ['International', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'Drama', 'Unscripted'],
#  ['Action', 'Comedy', 'Drama'],
#  ['International', 'Suspense'],
#  ['Drama', 'International', 'Suspense'],
#  ['Action', 'International'],
#  ['Kids'],
#  ['Anime', 'Drama', 'International'],
#  ['Drama'],
#  ['Action', 'Documentary', 'Sports'],
#  ['Documentary'],
#  ['Comedy', 'Horror'],
#  ['Action', 'Suspense'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['MusicVideosandConcerts'],
#  ['MusicVideosandConcerts'],
#  ['MusicVideosandConcerts'],
#  ['Action', 'Adventure', 'Anime'],
#  ['Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Suspense'],
#  ['Animation', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Suspense'],
#  ['Kids'],
#  ['Documentary'],
#  ['Sports'],
#  ['Western'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest'],
#  ['Western'],
#  ['Drama', 'Suspense'],
#  ['Documentary'],
#  ['Drama'],
#  ['Comedy'],
#  ['SpecialInterest', 'Sports'],
#  ['Horror'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Action', 'Drama'],
#  ['Comedy', 'International'],
#  ['SpecialInterest'],
#  ['Documentary', 'ScienceFiction'],
#  ['SpecialInterest'],
#  ['SpecialInterest'],
#  ['SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Horror', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Action', 'Comedy'],
#  ['Kids'],
#  ['Arthouse', 'Comedy', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary', 'SpecialInterest'],
#  ['Animation', 'International', 'Kids'],
#  ['Action', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Kids'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Documentary'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Comedy'],
#  ['Drama'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama'],
#  ['Kids', 'SpecialInterest'],
#  ['Animation', 'Kids'],
#  ['Action', 'Comedy'],
#  ['Drama', 'Suspense'],
#  ['Comedy', 'International'],
#  ['Horror', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['Kids', 'SpecialInterest'],
#  ['TVShows'],
#  ['Action', 'Suspense'],
#  ['Comedy', 'Drama', 'LGBTQ'],
#  ['Documentary', 'SpecialInterest'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['Action', 'Adventure'],
#  ['Comedy', 'Drama', 'Sports'],
#  ['Comedy', 'Romance'],
#  ['Documentary'],
#  ['MusicVideosandConcerts'],
#  ['TVShows'],
#  ['Documentary', 'Drama', 'Sports'],
#  ['Drama', 'International', 'Romance'],
#  ['Kids'],
#  ['Comedy', 'Documentary', 'Unscripted'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Suspense'],
#  ['Animation', 'Anime', 'Drama'],
#  ['Documentary'],
#  ['Documentary'],
#  ['Documentary'],
#  ['Unscripted'],
#  ['TVShows'],
#  ['Documentary'],
#  ['SpecialInterest'],
#  ['TVShows'],
#  ['Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Action', 'Adventure'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Animation', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Comedy', 'TalkShowandVariety'],
#  ['Animation', 'Kids'],
#  ['Action', 'Drama', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['MusicVideosandConcerts'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['TVShows'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Drama'],
#  ['Fantasy', 'Horror', 'International'],
#  ['Drama', 'International'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Animation', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Action', 'Animation', 'Kids'],
#  ['Drama', 'Romance'],
#  ['TVShows'],
#  ['Drama', 'International'],
#  ['Drama', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['MusicVideosandConcerts'],
#  ['Documentary'],
#  ['Kids'],
#  ['Animation', 'Kids'],
#  ['Drama', 'Suspense'],
#  ['Animation', 'Kids'],
#  ['SpecialInterest'],
#  ['Comedy', 'International'],
#  ['Comedy', 'International'],
#  ['Drama', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Western'],
#  ['Action', 'Drama', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Drama', 'Suspense'],
#  ['MusicVideosandConcerts'],
#  ['Action', 'Drama', 'International'],
#  ['Drama', 'Suspense'],
#  ['Action', 'Adventure', 'Suspense'],
#  ['Action', 'Drama', 'Suspense'],
#  ['MusicVideosandConcerts'],
#  ['Kids'],
#  ['Documentary', 'International'],
#  ['Drama'],
#  ['Action'],
#  ['Action', 'Drama', 'International'],
#  ['Action'],
#  ['Comedy'],
#  ['Adventure', 'Fantasy'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action', 'Romance', 'Western'],
#  ['Documentary', 'TalkShowandVariety'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Kids'],
#  ['Documentary', 'Drama', 'LGBTQ'],
#  ['Documentary', 'Sports', 'Unscripted'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy', 'Kids'],
#  ['Comedy', 'Kids'],
#  ['Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Horror', 'Suspense'],
#  ['Drama', 'International'],
#  ['Drama', 'International', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Horror'],
#  ['Action', 'Western'],
#  ['Drama'],
#  ['Kids'],
#  ['SpecialInterest'],
#  ['SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Drama', 'FaithandSpirituality', 'Romance'],
#  ['Horror', 'ScienceFiction'],
#  ['Documentary'],
#  ['Western'],
#  ['Horror', 'Suspense'],
#  ['Drama', 'Romance'],
#  ['Horror'],
#  ['Drama', 'FaithandSpirituality', 'LGBTQ'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Suspense', 'YoungAdultAudience'],
#  ['Documentary', 'SpecialInterest'],
#  ['Horror', 'Suspense'],
#  ['Drama', 'LGBTQ', 'Unscripted'],
#  ['Documentary', 'MusicVideosandConcerts'],
#  ['Documentary', 'MilitaryandWar'],
#  ['Comedy'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama', 'ScienceFiction', 'Suspense'],
#  ['Drama'],
#  ['Drama'],
#  ['Drama', 'MilitaryandWar'],
#  ['Documentary', 'Kids', 'SpecialInterest'],
#  ['TVShows'],
#  ['Drama', 'FaithandSpirituality'],
#  ['Documentary'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Suspense'],
#  ['Animation', 'Kids'],
#  ['Drama', 'FaithandSpirituality'],
#  ['Action', 'Drama'],
#  ['TVShows'],
#  ['Drama', 'Suspense'],
#  ['TVShows'],
#  ['Drama'],
#  ['Action', 'Comedy'],
#  ['SpecialInterest', 'Unscripted'],
#  ['Documentary'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'International', 'SpecialInterest'],
#  ['Drama', 'Horror', 'Suspense'],
#  ['Horror', 'Suspense'],
#  ['Horror', 'Suspense'],
#  ['Drama'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama', 'Suspense'],
#  ['Kids'],
#  ['Drama'],
#  ['Documentary'],
#  ['Documentary'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy'],
#  ['Kids'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'ScienceFiction', 'Suspense'],
#  ['Comedy'],
#  ['Drama', 'Horror', 'Suspense'],
#  ['Drama', 'Romance'],
#  ['Kids'],
#  ['Action', 'Drama'],
#  ['Animation', 'Kids'],
#  ['Action', 'Fantasy'],
#  ['TVShows'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary'],
#  ['Action', 'Drama', 'International'],
#  ['Suspense'],
#  ['Drama', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama'],
#  ['Comedy', 'ScienceFiction'],
#  ['Drama', 'Romance'],
#  ['Documentary'],
#  ['Horror'],
#  ['Comedy'],
#  ['TVShows'],
#  ['MusicVideosandConcerts'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Documentary'],
#  ['SpecialInterest'],
#  ['Action', 'Drama', 'Horror'],
#  ['Comedy', 'Kids'],
#  ['International', 'MusicVideosandConcerts', 'Unscripted'],
#  ['Documentary', 'Sports'],
#  ['Action', 'Kids'],
#  ['Action', 'Drama', 'Romance'],
#  ['MusicVideosandConcerts'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Documentary', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Drama', 'Sports'],
#  ['Documentary'],
#  ['Action', 'Drama'],
#  ['Kids', 'SpecialInterest'],
#  ['MusicVideosandConcerts'],
#  ['Documentary', 'Drama', 'SpecialInterest'],
#  ['Action', 'Suspense'],
#  ['Kids'],
#  ['Animation', 'Comedy', 'ScienceFiction'],
#  ['Horror'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama'],
#  ['Comedy'],
#  ['Documentary', 'International', 'SpecialInterest'],
#  ['TVShows'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest'],
#  ['Adventure', 'Drama'],
#  ['MusicVideosandConcerts'],
#  ['Comedy'],
#  ['Comedy', 'Western'],
#  ['Action', 'Western'],
#  ['Comedy'],
#  ['Animation', 'Kids'],
#  ['MusicVideosandConcerts'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'ScienceFiction'],
#  ['Documentary', 'SpecialInterest'],
#  ['Animation', 'Kids', 'SpecialInterest'],
#  ['Drama', 'MilitaryandWar'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Comedy'],
#  ['Action', 'Suspense'],
#  ['Animation', 'Kids'],
#  ['Comedy'],
#  ['Drama', 'Unscripted', 'YoungAdultAudience'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Action', 'Adventure'],
#  ['Drama', 'Suspense'],
#  ['Drama', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['TVShows'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary'],
#  ['Action', 'Drama'],
#  ['TVShows'],
#  ['Drama', 'Kids'],
#  ['Documentary', 'Horror'],
#  ['Drama', 'Suspense'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Documentary'],
#  ['Horror', 'Suspense'],
#  ['Action', 'Animation', 'Kids'],
#  ['Comedy', 'Suspense'],
#  ['TVShows'],
#  ['Animation', 'Drama', 'FaithandSpirituality'],
#  ['Kids'],
#  ['Drama', 'Historical'],
#  ['SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy', 'Drama'],
#  ['Action'],
#  ['Drama', 'ScienceFiction'],
#  ['Comedy', 'Documentary', 'SpecialInterest'],
#  ['Action', 'Drama', 'Historical'],
#  ['Western'],
#  ['Western'],
#  ['Anime'],
#  ['Anime', 'Kids'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Documentary', 'Drama', 'Unscripted'],
#  ['Drama', 'Kids'],
#  ['Drama'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Anime', 'Kids'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama', 'Romance', 'Suspense'],
#  ['MusicVideosandConcerts'],
#  ['Romance', 'ScienceFiction'],
#  ['Documentary', 'Sports'],
#  ['Horror', 'Suspense'],
#  ['Kids'],
#  ['Action', 'Western'],
#  ['Drama', 'Suspense'],
#  ['Drama', 'Historical'],
#  ['Documentary'],
#  ['Action', 'ScienceFiction'],
#  ['Drama', 'Historical', 'MilitaryandWar'],
#  ['Drama'],
#  ['Documentary'],
#  ['Drama'],
#  ['Drama', 'FaithandSpirituality', 'Suspense'],
#  ['Drama', 'MilitaryandWar'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Documentary'],
#  ['Drama', 'Suspense'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Suspense'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest'],
#  ['Action', 'Suspense'],
#  ['Action', 'Western'],
#  ['Action', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Kids'],
#  ['Comedy'],
#  ['Action', 'Drama', 'Western'],
#  ['Comedy'],
#  ['Documentary'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Drama'],
#  ['Action', 'Comedy'],
#  ['Documentary', 'SpecialInterest', 'Unscripted'],
#  ['Adventure'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Suspense'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'YoungAdultAudience'],
#  ['Drama', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['TVShows'],
#  ['Documentary', 'Drama', 'Sports'],
#  ['Documentary', 'SpecialInterest'],
#  ['TVShows'],
#  ['Drama', 'International'],
#  ['SpecialInterest'],
#  ['Action', 'SpecialInterest'],
#  ['Drama'],
#  ['Drama', 'Suspense'],
#  ['Comedy'],
#  ['Documentary', 'SpecialInterest'],
#  ['Horror'],
#  ['MusicVideosandConcerts'],
#  ['ScienceFiction'],
#  ['Drama'],
#  ['Documentary'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Documentary', 'Unscripted'],
#  ['Horror', 'Suspense'],
#  ['Horror', 'Suspense'],
#  ['Action', 'Suspense'],
#  ['Documentary', 'SpecialInterest', 'Sports'],
#  ['Documentary'],
#  ['Drama'],
#  ['Action', 'Drama'],
#  ['Drama'],
#  ['Unscripted'],
#  ['Documentary'],
#  ['Kids', 'SpecialInterest', 'Unscripted'],
#  ['Comedy', 'Documentary', 'Sports'],
#  ['Drama'],
#  ['Documentary'],
#  ['Arts',
#   'Entertainment',
#   'andCulture',
#   'Documentary',
#   'MusicVideosandConcerts'],
#  ['TVShows'],
#  ['Documentary'],
#  ['Drama', 'ScienceFiction'],
#  ['Documentary', 'Drama', 'Unscripted'],
#  ['Horror', 'Unscripted'],
#  ['Documentary', 'Drama'],
#  ['Suspense', 'Western'],
#  ['Animation', 'Kids'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['TVShows'],
#  ['Action', 'Drama', 'International'],
#  ['Documentary', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Romance'],
#  ['Comedy'],
#  ['SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['TVShows'],
#  ['TVShows'],
#  ['Action', 'Romance', 'Western'],
#  ['Documentary'],
#  ['Drama'],
#  ['Documentary'],
#  ['Suspense'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Romance', 'ScienceFiction'],
#  ['Western'],
#  ['Drama'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['TVShows'],
#  ['FaithandSpirituality'],
#  ['Documentary'],
#  ['Action', 'Comedy'],
#  ['Action', 'ScienceFiction'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'Sports'],
#  ['MusicVideosandConcerts'],
#  ['TVShows'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['Action', 'Drama'],
#  ['Documentary'],
#  ['Drama', 'Historical', 'International'],
#  ['Action', 'Kids', 'ScienceFiction'],
#  ['Drama', 'Suspense'],
#  ['Animation', 'Comedy', 'Kids'],
#  ['Comedy', 'Kids'],
#  ['Horror', 'Suspense'],
#  ['Documentary', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Documentary', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Action', 'MilitaryandWar'],
#  ['Animation', 'Kids'],
#  ['Action', 'Horror'],
#  ['YoungAdultAudience'],
#  ['TVShows'],
#  ['Horror', 'YoungAdultAudience'],
#  ['Horror'],
#  ['Horror'],
#  ['Documentary', 'SpecialInterest'],
#  ['Horror', 'ScienceFiction'],
#  ['Western'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Action', 'Comedy'],
#  ['Drama'],
#  ['Drama'],
#  ['Documentary'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Romance'],
#  ['Action', 'Horror', 'Suspense'],
#  ['Horror'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Kids'],
#  ['Drama', 'FaithandSpirituality', 'Romance'],
#  ['Drama'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Western'],
#  ['Action', 'Animation', 'Kids'],
#  ['SpecialInterest'],
#  ['Action', 'Drama'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action'],
#  ['Drama'],
#  ['TVShows'],
#  ['SpecialInterest', 'Unscripted'],
#  ['Drama'],
#  ['Documentary'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['MusicVideosandConcerts'],
#  ['Action', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Comedy', 'Kids'],
#  ['Comedy'],
#  ['Kids'],
#  ['Comedy', 'Drama', 'Kids'],
#  ['Drama'],
#  ['Documentary'],
#  ['Comedy'],
#  ['Action', 'Fantasy', 'ScienceFiction'],
#  ['Documentary'],
#  ['Drama', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Suspense'],
#  ['TVShows'],
#  ['Horror', 'Suspense'],
#  ['Action', 'Suspense'],
#  ['Action', 'ScienceFiction'],
#  ['Action', 'Suspense'],
#  ['MusicVideosandConcerts'],
#  ['MusicVideosandConcerts'],
#  ['ScienceFiction'],
#  ['Documentary'],
#  ['Documentary', 'FaithandSpirituality'],
#  ['TVShows'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Documentary'],
#  ['Drama', 'SpecialInterest', 'Unscripted'],
#  ['Documentary', 'SpecialInterest'],
#  ['Documentary', 'MilitaryandWar'],
#  ['SpecialInterest'],
#  ['TVShows'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'ScienceFiction'],
#  ['Adventure', 'Drama', 'MilitaryandWar'],
#  ['Comedy', 'Drama'],
#  ['TVShows'],
#  ['Action', 'Animation', 'Kids'],
#  ['Drama', 'MilitaryandWar'],
#  ['Drama'],
#  ['Documentary', 'Drama', 'Sports'],
#  ['Action', 'Adventure'],
#  ['Comedy'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama'],
#  ['Drama'],
#  ['MusicVideosandConcerts'],
#  ['Drama', 'Western'],
#  ['Western'],
#  ['Action'],
#  ['ScienceFiction'],
#  ['Drama', 'Suspense'],
#  ['Comedy', 'Drama', 'LGBTQ'],
#  ['Anime', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Adventure', 'Drama'],
#  ['Kids'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'International'],
#  ['Action', 'Suspense'],
#  ['TVShows'],
#  ['Comedy', 'Horror'],
#  ['Documentary', 'Unscripted'],
#  ['Adventure', 'Documentary', 'MilitaryandWar'],
#  ['Documentary'],
#  ['Kids'],
#  ['Animation', 'Kids'],
#  ['Animation', 'Kids'],
#  ['Documentary', 'Kids'],
#  ['Documentary', 'SpecialInterest'],
#  ['Unscripted'],
#  ['Action', 'Adventure'],
#  ['Action'],
#  ['MilitaryandWar', 'SpecialInterest'],
#  ['Drama'],
#  ['Arthouse', 'Drama', 'Suspense'],
#  ['Comedy', 'Drama', 'International'],
#  ['Horror'],
#  ['MusicVideosandConcerts'],
#  ['ScienceFiction'],
#  ['Comedy'],
#  ['TVShows'],
#  ['Comedy', 'International', 'YoungAdultAudience'],
#  ['Animation', 'Kids'],
#  ['Kids'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Action'],
#  ['Action', 'Anime', 'Fantasy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Kids'],
#  ['Comedy'],
#  ['Comedy'],
#  ['TVShows'],
#  ['Documentary', 'SpecialInterest', 'Suspense'],
#  ['Unscripted'],
#  ['Documentary'],
#  ['SpecialInterest'],
#  ['Action', 'Adventure', 'Documentary'],
#  ['Unscripted'],
#  ['SpecialInterest'],
#  ['Documentary', 'SpecialInterest'],
#  ['Animation', 'FaithandSpirituality', 'Kids'],
#  ['Comedy', 'Documentary', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Kids'],
#  ['Animation', 'Documentary', 'Kids'],
#  ['Animation', 'Documentary', 'Kids'],
#  ['Animation', 'Kids', 'Sports'],
#  ['Animation', 'Kids', 'Sports'],
#  ['Animation', 'Documentary', 'Kids'],
#  ['Arthouse', 'Drama', 'Romance'],
#  ['TVShows'],
#  ['TVShows'],
#  ['Documentary', 'SpecialInterest'],
#  ['Western'],
#  ['Documentary', 'SpecialInterest'],
#  ['Action', 'Drama'],
#  ['Animation', 'Kids'],
#  ['Western'],
#  ['Drama', 'MilitaryandWar'],
#  ['SpecialInterest'],
#  ['Drama'],
#  ['Action', 'Drama', 'Horror'],
#  ['Drama', 'International'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'SpecialInterest', 'Sports'],
#  ['Drama', 'International'],
#  ['Action', 'Suspense'],
#  ['Documentary', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Action', 'Drama'],
#  ['Action', 'YoungAdultAudience'],
#  ['TVShows'],
#  ['Drama', 'Western'],
#  ['Western'],
#  ['Animation', 'Kids'],
#  ['Drama', 'FaithandSpirituality', 'Kids'],
#  ['TVShows'],
#  ['Unscripted'],
#  ['TVShows'],
#  ['TVShows'],
#  ['Documentary', 'MusicVideosandConcerts'],
#  ['Comedy', 'Horror'],
#  ['Comedy'],
#  ['Arthouse', 'Drama'],
#  ['Comedy'],
#  ['Adventure', 'Animation', 'Kids'],
#  ['Documentary', 'SpecialInterest'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Documentary', 'SpecialInterest', 'Unscripted'],
#  ['Horror', 'Suspense'],
#  ['Action', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Documentary', 'Sports'],
#  ['Drama', 'Suspense'],
#  ['TVShows'],
#  ['TVShows'],
#  ['Drama', 'ScienceFiction', 'SpecialInterest'],
#  ['Drama', 'ScienceFiction', 'SpecialInterest'],
#  ['ScienceFiction'],
#  ['Drama', 'ScienceFiction', 'SpecialInterest'],
#  ['Action', 'Adventure', 'ScienceFiction'],
#  ['ScienceFiction'],
#  ['Documentary'],
#  ['TVShows'],
#  ['Drama', 'Suspense'],
#  ['Drama'],
#  ['Suspense'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'MilitaryandWar'],
#  ['Western'],
#  ['Drama'],
#  ['Comedy', 'Horror'],
#  ['Kids'],
#  ['Drama', 'Kids'],
#  ['TVShows'],
#  ['Drama', 'Kids'],
#  ['SpecialInterest'],
#  ['Drama'],
#  ['Documentary', 'Sports'],
#  ['Action', 'Drama'],
#  ['Documentary'],
#  ['Western'],
#  ['Drama', 'Horror'],
#  ['Documentary', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['SpecialInterest'],
#  ['SpecialInterest'],
#  ['Comedy', 'International'],
#  ['Documentary', 'Drama', 'Sports'],
#  ['Animation', 'Anime', 'Kids'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Fantasy', 'Kids'],
#  ['Western'],
#  ['Action'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Western'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure'],
#  ['Comedy', 'Drama', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Documentary', 'MusicVideosandConcerts'],
#  ['MusicVideosandConcerts'],
#  ['Animation', 'Comedy'],
#  ['Drama'],
#  ['Kids', 'ScienceFiction'],
#  ['Action', 'Suspense'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action', 'Comedy'],
#  ['TVShows'],
#  ['MusicVideosandConcerts'],
#  ['Kids'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Comedy', 'Kids'],
#  ['TVShows'],
#  ['Comedy', 'Drama', 'YoungAdultAudience'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama', 'LGBTQ'],
#  ['Action'],
#  ['Drama', 'International'],
#  ['Drama'],
#  ['Action', 'ScienceFiction'],
#  ['Drama'],
#  ['SpecialInterest', 'Sports'],
#  ['Fantasy', 'ScienceFiction'],
#  ['Comedy'],
#  ['Drama', 'Suspense'],
#  ['Action'],
#  ['Comedy', 'Kids'],
#  ['Action', 'ScienceFiction'],
#  ['Action', 'Kids'],
#  ['International', 'Unscripted'],
#  ['Documentary'],
#  ['Arthouse', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Sports', 'Unscripted'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Documentary', 'SpecialInterest'],
#  ['Drama', 'International'],
#  ['Comedy'],
#  ['Documentary', 'SpecialInterest', 'Sports'],
#  ['Kids'],
#  ['Kids'],
#  ['Kids'],
#  ['Drama', 'Suspense'],
#  ['Kids'],
#  ['Kids'],
#  ['Kids'],
#  ['Kids'],
#  ['Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Documentary'],
#  ...]

# %%
gen=[]
for i in r:
    gen+=i
gen
# Out:
# ['Comedy',
#  'Drama',
#  'Drama',
#  'International',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Fantasy',
#  'Kids',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'Action',
#  'ScienceFiction',
#  'Suspense',
#  'Drama',
#  'Adventure',
#  'Kids',
#  'Comedy',
#  'Horror',
#  'Suspense',
#  'Documentary',
#  'Sports',
#  'Documentary',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'ScienceFiction',
#  'Kids',
#  'SpecialInterest',
#  'Comedy',
#  'TalkShowandVariety',
#  'ScienceFiction',
#  'Kids',
#  'Action',
#  'Anime',
#  'Comedy',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'Drama',
#  'TVShows',
#  'Drama',
#  'Documentary',
#  'TVShows',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Anime',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Anime',
#  'Kids',
#  'TVShows',
#  'Drama',
#  'MusicVideosandConcerts',
#  'MusicVideosandConcerts',
#  'Drama',
#  'Suspense',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Fitness',
#  'SpecialInterest',
#  'FaithandSpirituality',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Fitness',
#  'Fitness',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'Fitness',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Action',
#  'MilitaryandWar',
#  'Western',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'TalkShowandVariety',
#  'Drama',
#  'International',
#  'Drama',
#  'International',
#  'Action',
#  'Western',
#  'Documentary',
#  'ScienceFiction',
#  'Adventure',
#  'Animation',
#  'Kids',
#  'Fantasy',
#  'ScienceFiction',
#  'Suspense',
#  'Suspense',
#  'Action',
#  'Documentary',
#  'LGBTQ',
#  'Drama',
#  'Romance',
#  'Suspense',
#  'Comedy',
#  'SpecialInterest',
#  'Unscripted',
#  'TVShows',
#  'Unscripted',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'MilitaryandWar',
#  'MusicVideosandConcerts',
#  'TVShows',
#  'Kids',
#  'Drama',
#  'Kids',
#  'Documentary',
#  'SpecialInterest',
#  'Kids',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Action',
#  'Drama',
#  'Drama',
#  'Suspense',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Kids',
#  'TVShows',
#  'Comedy',
#  'Documentary',
#  'Unscripted',
#  'Comedy',
#  'Documentary',
#  'Unscripted',
#  'Action',
#  'Drama',
#  'Western',
#  'Action',
#  'Drama',
#  'Sports',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Documentary',
#  'International',
#  'SpecialInterest',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'ScienceFiction',
#  'Documentary',
#  'SpecialInterest',
#  'Kids',
#  'Action',
#  'Documentary',
#  'SpecialInterest',
#  'Drama',
#  'Western',
#  'Documentary',
#  'TVShows',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Drama',
#  'SpecialInterest',
#  'Documentary',
#  'Comedy',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Drama',
#  'Suspense',
#  'Action',
#  'ScienceFiction',
#  'Documentary',
#  'FaithandSpirituality',
#  'SpecialInterest',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'SpecialInterest',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Drama',
#  'YoungAdultAudience',
#  'Drama',
#  'MilitaryandWar',
#  'Drama',
#  'Arthouse',
#  'Drama',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'Kids',
#  'SpecialInterest',
#  'Unscripted',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'Suspense',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Sports',
#  'MilitaryandWar',
#  'Western',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Kids',
#  'Kids',
#  'Anime',
#  'TVShows',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'International',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'TVShows',
#  'Kids',
#  'Comedy',
#  'Documentary',
#  'SpecialInterest',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Suspense',
#  'SpecialInterest',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Kids',
#  'Animation',
#  'Comedy',
#  'Kids',
#  'Action',
#  'Suspense',
#  'Western',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Suspense',
#  'Documentary',
#  'Sports',
#  'Action',
#  'Drama',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Unscripted',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'ScienceFiction',
#  'Drama',
#  'Suspense',
#  'Action',
#  'ScienceFiction',
#  'Suspense',
#  'Drama',
#  'Suspense',
#  'TVShows',
#  'Kids',
#  'Action',
#  'Drama',
#  'International',
#  'Drama',
#  'Drama',
#  'ScienceFiction',
#  'Suspense',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Anime',
#  'International',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Documentary',
#  'International',
#  'SpecialInterest',
#  'TVShows',
#  'Documentary',
#  'International',
#  'Suspense',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'Drama',
#  'Unscripted',
#  'Action',
#  'Comedy',
#  'Drama',
#  'International',
#  'Suspense',
#  'Drama',
#  'International',
#  'Suspense',
#  'Action',
#  'International',
#  'Kids',
#  'Anime',
#  'Drama',
#  'International',
#  'Drama',
#  'Action',
#  'Documentary',
#  'Sports',
#  'Documentary',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Drama',
#  'Suspense',
#  'Drama',
#  'MusicVideosandConcerts',
#  'MusicVideosandConcerts',
#  'MusicVideosandConcerts',
#  'Action',
#  'Adventure',
#  'Anime',
#  'Comedy',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Suspense',
#  'Animation',
#  'Drama',
#  'Drama',
#  'Drama',
#  'Suspense',
#  'Kids',
#  'Documentary',
#  'Sports',
#  'Western',
#  'Drama',
#  'Romance',
#  'Documentary',
#  'SpecialInterest',
#  'Western',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'Drama',
#  'Comedy',
#  'SpecialInterest',
#  'Sports',
#  'Horror',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Comedy',
#  'International',
#  'SpecialInterest',
#  'Documentary',
#  'ScienceFiction',
#  'SpecialInterest',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'Horror',
#  'Suspense',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Action',
#  'Comedy',
#  'Kids',
#  'Arthouse',
#  'Comedy',
#  'Drama',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Documentary',
#  'SpecialInterest',
#  'Animation',
#  'International',
#  'Kids',
#  'Action',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Kids',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Documentary',
#  'SpecialInterest',
#  'Drama',
#  'Kids',
#  'SpecialInterest',
#  'Animation',
#  'Kids',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Suspense',
#  'Comedy',
#  'International',
#  'Horror',
#  'Suspense',
#  'Documentary',
#  'SpecialInterest',
#  'Kids',
#  'SpecialInterest',
#  'TVShows',
#  'Action',
#  'Suspense',
#  'Comedy',
#  'Drama',
#  'LGBTQ',
#  'Documentary',
#  'SpecialInterest',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'SpecialInterest',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Sports',
#  'Comedy',
#  'Romance',
#  'Documentary',
#  'MusicVideosandConcerts',
#  'TVShows',
#  'Documentary',
#  'Drama',
#  'Sports',
#  'Drama',
#  'International',
#  'Romance',
#  'Kids',
#  'Comedy',
#  'Documentary',
#  'Unscripted',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Horror',
#  'Suspense',
#  'Animation',
#  'Anime',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'Unscripted',
#  'TVShows',
#  'Documentary',
#  'SpecialInterest',
#  'TVShows',
#  'Drama',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Action',
#  'Adventure',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Animation',
#  'Kids',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Comedy',
#  'TalkShowandVariety',
#  'Animation',
#  'Kids',
#  'Action',
#  'Drama',
#  'Kids',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'MusicVideosandConcerts',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'TVShows',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'International',
#  'Drama',
#  'International',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Animation',
#  'Kids',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Action',
#  'Animation',
#  'Kids',
#  'Drama',
#  'Romance',
#  'TVShows',
#  'Drama',
#  'International',
#  'Drama',
#  'Suspense',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'MusicVideosandConcerts',
#  'Documentary',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Drama',
#  'Suspense',
#  'Animation',
#  'Kids',
#  'SpecialInterest',
#  'Comedy',
#  'International',
#  'Comedy',
#  'International',
#  'Drama',
#  'FaithandSpirituality',
#  'SpecialInterest',
#  'Western',
#  'Action',
#  'Drama',
#  'Western',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Drama',
#  'Suspense',
#  'MusicVideosandConcerts',
#  'Action',
#  'Drama',
#  'International',
#  'Drama',
#  'Suspense',
#  'Action',
#  'Adventure',
#  'Suspense',
#  'Action',
#  'Drama',
#  'Suspense',
#  'MusicVideosandConcerts',
#  'Kids',
#  'Documentary',
#  'International',
#  'Drama',
#  'Action',
#  'Action',
#  'Drama',
#  'International',
#  'Action',
#  'Comedy',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Romance',
#  'Western',
#  'Documentary',
#  'TalkShowandVariety',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Animation',
#  'Kids',
#  'Kids',
#  'Documentary',
#  'Drama',
#  'LGBTQ',
#  'Documentary',
#  'Sports',
#  'Unscripted',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'Kids',
#  'Comedy',
#  'Kids',
#  'Drama',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'International',
#  'Drama',
#  'International',
#  'Romance',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Western',
#  'Drama',
#  'Kids',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'MusicVideosandConcerts',
#  'SpecialInterest',
#  'SpecialInterest',
#  'Drama',
#  'FaithandSpirituality',
#  'Romance',
#  'Horror',
#  'ScienceFiction',
#  'Documentary',
#  'Western',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'Romance',
#  'Horror',
#  'Drama',
#  'FaithandSpirituality',
#  'LGBTQ',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Suspense',
#  'YoungAdultAudience',
#  'Documentary',
#  'SpecialInterest',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'LGBTQ',
#  'Unscripted',
#  'Documentary',
#  'MusicVideosandConcerts',
#  'Documentary',
#  'MilitaryandWar',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Drama',
#  'ScienceFiction',
#  'Suspense',
#  'Drama',
#  'Drama',
#  'Drama',
#  'MilitaryandWar',
#  'Documentary',
#  'Kids',
#  'SpecialInterest',
#  'TVShows',
#  'Drama',
#  'FaithandSpirituality',
#  'Documentary',
#  'Drama',
#  'Romance',
#  'Drama',
#  'Suspense',
#  'Animation',
#  'Kids',
#  'Drama',
#  'FaithandSpirituality',
#  'Action',
#  'Drama',
#  'TVShows',
#  'Drama',
#  'Suspense',
#  'TVShows',
#  'Drama',
#  'Action',
#  'Comedy',
#  'SpecialInterest',
#  'Unscripted',
#  'Documentary',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'International',
#  'SpecialInterest',
#  'Drama',
#  'Horror',
#  'Suspense',
#  'Horror',
#  'Suspense',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'Documentary',
#  'SpecialInterest',
#  'Drama',
#  'Suspense',
#  'Kids',
#  'Drama',
#  'Documentary',
#  'Documentary',
#  'Documentary',
#  'SpecialInterest',
#  'Comedy',
#  'Kids',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Drama',
#  'ScienceFiction',
#  'Suspense',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Suspense',
#  'Drama',
#  'Romance',
#  'Kids',
#  'Action',
#  'Drama',
#  'Animation',
#  'Kids',
#  'Action',
#  'Fantasy',
#  'TVShows',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Arts',
#  'Entertainment',
#  'andCulture',
#  'Comedy',
#  'SpecialInterest',
#  'Documentary',
#  'SpecialInterest',
#  'Documentary',
#  'Action',
#  'Drama',
#  'International',
#  'Suspense',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'SpecialInterest',
#  'Drama',
#  'Comedy',
#  'ScienceFiction',
#  'Drama',
#  'Romance',
#  'Documentary',
#  'Horror',
#  'Comedy',
#  'TVShows',
#  'MusicVideosandConcerts',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Documentary',
#  'SpecialInterest',
#  'Action',
#  'Drama',
#  'Horror',
#  'Comedy',
#  'Kids',
#  'International',
#  'MusicVideosandConcerts',
#  'Unscripted',
#  'Documentary',
#  'Sports',
#  'Action',
#  'Kids',
#  'Action',
#  'Drama',
#  'Romance',
#  'MusicVideosandConcerts',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'FaithandSpirituality',
#  'SpecialInterest',
#  'Drama',
#  'Sports',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Kids',
#  'SpecialInterest',
#  'MusicVideosandConcerts',
#  'Documentary',
#  'Drama',
#  'SpecialInterest',
#  'Action',
#  'Suspense',
#  'Kids',
#  'Animation',
#  'Comedy',
#  'ScienceFiction',
#  'Horror',
#  'Documentary',
#  'SpecialInterest',
#  'Drama',
#  'Comedy',
#  'Documentary',
#  'International',
#  'SpecialInterest',
#  'TVShows',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'Romance',
#  'Documentary',
#  'SpecialInterest',
#  'Adventure',
#  'Drama',
#  'MusicVideosandConcerts',
#  'Comedy',
#  'Comedy',
#  'Western',
#  'Action',
#  'Western',
#  'Comedy',
#  'Animation',
#  'Kids',
#  'MusicVideosandConcerts',
#  'Comedy',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'ScienceFiction',
#  'Documentary',
#  'SpecialInterest',
#  'Animation',
#  'Kids',
#  'SpecialInterest',
#  'Drama',
#  'MilitaryandWar',
#  'Action',
#  'Drama',
#  'Suspense',
#  'Comedy',
#  'Action',
#  'Suspense',
#  'Animation',
#  'Kids',
#  'Comedy',
#  'Drama',
#  'Unscripted',
#  'YoungAdultAudience',
#  'Documentary',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Suspense',
#  'Drama',
#  'Suspense',
#  'Documentary',
#  'SpecialInterest',
#  'TVShows',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Documentary',
#  ...]

# %%
listacantidad=[]
for i in f1:
    if i in gen:
        listacantidad.append(gen.count(i))
print(listacantidad)
# Out:
# [83, 483, 547, 160, 993, 1085, 1657, 483, 980, 31, 44, 875, 263, 87, 1501, 259, 14, 483, 113, 674, 3687, 80, 155, 68, 152, 355, 457, 141, 66, 2099, 234]

# %%
dic={'Fitness':83, 'andCulture':483, 'Animation':547, 'Sports':160, 'Documentary':993, 'Kids':1085, 'Action':1657, 'Arts':483, 'SpecialInterest':980, 'Historical':31, 'MilitaryandWar':44, 'Horror':875, 'TVShows':263, 'YoungAdultAudience':87, 'Suspense':1501, 'Adventure':259, 'TalkShowandVariety':14, 'Entertainment':483, 'LGBTQ':113, 'Romance':674, 'Drama':3687, 'Anime':80, 'MusicVideosandConcerts':155, 'Fantasy':68, 'Unscripted':152, 'International':355, 'ScienceFiction':457, 'Arthouse':141, 'FaithandSpirituality':66, 'Comedy':2099, 'Western':234}
dic
# Out:
# {'Fitness': 83,
#  'andCulture': 483,
#  'Animation': 547,
#  'Sports': 160,
#  'Documentary': 993,
#  'Kids': 1085,
#  'Action': 1657,
#  'Arts': 483,
#  'SpecialInterest': 980,
#  'Historical': 31,
#  'MilitaryandWar': 44,
#  'Horror': 875,
#  'TVShows': 263,
#  'YoungAdultAudience': 87,
#  'Suspense': 1501,
#  'Adventure': 259,
#  'TalkShowandVariety': 14,
#  'Entertainment': 483,
#  'LGBTQ': 113,
#  'Romance': 674,
#  'Drama': 3687,
#  'Anime': 80,
#  'MusicVideosandConcerts': 155,
#  'Fantasy': 68,
#  'Unscripted': 152,
#  'International': 355,
#  'ScienceFiction': 457,
#  'Arthouse': 141,
#  'FaithandSpirituality': 66,
#  'Comedy': 2099,
#  'Western': 234}

# %%
generomasrep=max(dic, key=dic.get)
generomasrep
# Out:
# 'Drama'

# %%
frec=dic.get("comedy")
frec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [933], line 1
# ----> 1 frec=dic.get(comedy)
#       2 frec
#
# NameError: name 'comedy' is not defined

# %%
print("el genero que mas frecuencias tiene es",generomasrep,"con",frec,"repeticiones dentro de AMazon")
# Out:
# el genero que mas frecuencias tiene es Drama con 3687 repeticiones dentro de AMazon

# %%
def get_listedin(genero):
    dic={'Fitness':83, 'andCulture':483, 'Animation':547, 'Sports':160, 'Documentary':993, 'Kids':1085, 'Action':1657, 'Arts':483, 'SpecialInterest':980, 'Historical':31, 'MilitaryandWar':44, 'Horror':875, 'TVShows':263, 'YoungAdultAudience':87, 'Suspense':1501, 'Adventure':259, 'TalkShowandVariety':14, 'Entertainment':483, 'LGBTQ':113, 'Romance':674, 'Drama':3687, 'Anime':80, 'MusicVideosandConcerts':155, 'Fantasy':68, 'Unscripted':152, 'International':355, 'ScienceFiction':457, 'Arthouse':141, 'FaithandSpirituality':66, 'Comedy':2099, 'Western':234}
    if genero=="comedy":
        return dic['Comedy']
    if genero=="action":
        return dic['Action']
    if genero=="suspense":
        return dic['Suspense']
    if genero=="drama":
        return dic['Drama']

# %%
get_listedin("drama")
# Out:
# 3687

# %%
x=amazon['listed_in'].unique().tolist()
y=[]
for i in x:
    y.append(i.split(","))
y
# Out:
# [['Comedy', 'Drama'],
#  ['Drama', 'International'],
#  ['Action', 'Drama', 'Suspense'],
#  ['Documentary'],
#  ['Drama', 'Fantasy'],
#  ['Fantasy', 'Kids'],
#  ['Documentary', 'SpecialInterest'],
#  ['Comedy'],
#  ['Action', 'ScienceFiction', 'Suspense'],
#  ['Drama'],
#  ['Adventure', 'Kids'],
#  ['Horror', 'Suspense'],
#  ['Documentary', 'Sports'],
#  ['Horror', 'ScienceFiction'],
#  ['Kids', 'SpecialInterest'],
#  ['Comedy', 'TalkShowandVariety'],
#  ['ScienceFiction'],
#  ['Kids'],
#  ['Action', 'Anime', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Drama'],
#  ['TVShows'],
#  ['Animation', 'Anime', 'Fantasy'],
#  ['Action', 'Adventure', 'Animation'],
#  ['Anime', 'Kids'],
#  ['MusicVideosandConcerts'],
#  ['Drama', 'Suspense'],
#  ['Fitness', 'SpecialInterest'],
#  ['FaithandSpirituality', 'SpecialInterest'],
#  ['SpecialInterest'],
#  ['Fitness'],
#  ['Action', 'MilitaryandWar', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'TalkShowandVariety'],
#  ['Action', 'Western'],
#  ['Documentary', 'ScienceFiction'],
#  ['Adventure', 'Animation', 'Kids'],
#  ['Fantasy', 'ScienceFiction', 'Suspense'],
#  ['Suspense'],
#  ['Action'],
#  ['Documentary', 'LGBTQ'],
#  ['Drama', 'Romance', 'Suspense'],
#  ['Comedy', 'SpecialInterest', 'Unscripted'],
#  ['Unscripted'],
#  ['Documentary', 'MilitaryandWar'],
#  ['Animation', 'Kids'],
#  ['Action', 'Drama'],
#  ['Comedy', 'Documentary', 'Unscripted'],
#  ['Western'],
#  ['Action', 'Drama', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest'],
#  ['Documentary', 'International', 'SpecialInterest'],
#  ['Comedy', 'ScienceFiction'],
#  ['Drama', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture'],
#  ['Drama', 'SpecialInterest'],
#  ['Action', 'ScienceFiction'],
#  ['Documentary', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Action', 'Drama', 'SpecialInterest'],
#  ['Drama', 'YoungAdultAudience'],
#  ['Drama', 'MilitaryandWar'],
#  ['Arthouse', 'Drama'],
#  ['Documentary', 'Kids', 'SpecialInterest'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Sports'],
#  ['MilitaryandWar', 'Western'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Anime'],
#  ['Comedy', 'International'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Horror', 'Suspense'],
#  ['Animation', 'Comedy', 'Kids'],
#  ['Action', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary'],
#  ['Documentary', 'Drama', 'Unscripted'],
#  ['Action', 'Drama', 'International'],
#  ['Drama', 'ScienceFiction', 'Suspense'],
#  ['International', 'Suspense'],
#  ['Drama', 'International', 'Suspense'],
#  ['Action', 'International'],
#  ['Anime', 'Drama', 'International'],
#  ['Action', 'Documentary', 'Sports'],
#  ['Comedy', 'Horror'],
#  ['Action', 'Adventure', 'Anime'],
#  ['Animation', 'Drama'],
#  ['SpecialInterest', 'Sports'],
#  ['Horror'],
#  ['Action', 'Comedy'],
#  ['Arthouse', 'Comedy', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary', 'SpecialInterest'],
#  ['Animation', 'International', 'Kids'],
#  ['Comedy', 'Drama', 'LGBTQ'],
#  ['Action', 'Adventure'],
#  ['Comedy', 'Drama', 'Sports'],
#  ['Comedy', 'Romance'],
#  ['Documentary', 'Drama', 'Sports'],
#  ['Drama', 'International', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Animation', 'Anime', 'Drama'],
#  ['Action', 'Drama', 'Kids'],
#  ['Fantasy', 'Horror', 'International'],
#  ['Action', 'Animation', 'Kids'],
#  ['Drama', 'FaithandSpirituality', 'SpecialInterest'],
#  ['Action', 'Drama', 'Western'],
#  ['Action', 'Adventure', 'Suspense'],
#  ['Documentary', 'International'],
#  ['Adventure', 'Fantasy'],
#  ['Action', 'Romance', 'Western'],
#  ['Documentary', 'TalkShowandVariety'],
#  ['Documentary', 'Drama', 'LGBTQ'],
#  ['Documentary', 'Sports', 'Unscripted'],
#  ['Comedy', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['MusicVideosandConcerts', 'SpecialInterest'],
#  ['Drama', 'FaithandSpirituality', 'Romance'],
#  ['Drama', 'FaithandSpirituality', 'LGBTQ'],
#  ['Drama', 'Suspense', 'YoungAdultAudience'],
#  ['Drama', 'LGBTQ', 'Unscripted'],
#  ['Documentary', 'MusicVideosandConcerts'],
#  ['Drama', 'FaithandSpirituality'],
#  ['SpecialInterest', 'Unscripted'],
#  ['Action', 'Fantasy'],
#  ['Action', 'Drama', 'Horror'],
#  ['International', 'MusicVideosandConcerts', 'Unscripted'],
#  ['Action', 'Kids'],
#  ['Action', 'Drama', 'Romance'],
#  ['Drama', 'Sports'],
#  ['Documentary', 'Drama', 'SpecialInterest'],
#  ['Animation', 'Comedy', 'ScienceFiction'],
#  ['Adventure', 'Drama'],
#  ['Comedy', 'Western'],
#  ['Animation', 'Kids', 'SpecialInterest'],
#  ['Drama', 'Unscripted', 'YoungAdultAudience'],
#  ['Drama', 'Kids'],
#  ['Documentary', 'Horror'],
#  ['Action', 'Comedy', 'Horror'],
#  ['Comedy', 'Suspense'],
#  ['Animation', 'Drama', 'FaithandSpirituality'],
#  ['Drama', 'Historical'],
#  ['Drama', 'ScienceFiction'],
#  ['Comedy', 'Documentary', 'SpecialInterest'],
#  ['Action', 'Drama', 'Historical'],
#  ['Animation', 'Anime', 'Kids'],
#  ['Romance', 'ScienceFiction'],
#  ['Drama', 'Historical', 'MilitaryandWar'],
#  ['Drama', 'FaithandSpirituality', 'Suspense'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Documentary', 'SpecialInterest', 'Unscripted'],
#  ['Adventure'],
#  ['Comedy', 'YoungAdultAudience'],
#  ['Action', 'SpecialInterest'],
#  ['Action', 'Documentary', 'Unscripted'],
#  ['Documentary', 'SpecialInterest', 'Sports'],
#  ['Kids', 'SpecialInterest', 'Unscripted'],
#  ['Comedy', 'Documentary', 'Sports'],
#  ['Arts',
#   'Entertainment',
#   'andCulture',
#   'Documentary',
#   'MusicVideosandConcerts'],
#  ['Horror', 'Unscripted'],
#  ['Documentary', 'Drama'],
#  ['Suspense', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Romance'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['FaithandSpirituality'],
#  ['Drama', 'Historical', 'International'],
#  ['Action', 'Kids', 'ScienceFiction'],
#  ['Action', 'MilitaryandWar'],
#  ['Action', 'Horror'],
#  ['YoungAdultAudience'],
#  ['Horror', 'YoungAdultAudience'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Romance'],
#  ['Action', 'Horror', 'Suspense'],
#  ['Comedy', 'Drama', 'Kids'],
#  ['Action', 'Fantasy', 'ScienceFiction'],
#  ['Documentary', 'FaithandSpirituality'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Documentary'],
#  ['Drama', 'SpecialInterest', 'Unscripted'],
#  ['Adventure', 'Drama', 'MilitaryandWar'],
#  ['Documentary', 'Unscripted'],
#  ['Adventure', 'Documentary', 'MilitaryandWar'],
#  ['Documentary', 'Kids'],
#  ['MilitaryandWar', 'SpecialInterest'],
#  ['Arthouse', 'Drama', 'Suspense'],
#  ['Comedy', 'Drama', 'International'],
#  ['Comedy', 'International', 'YoungAdultAudience'],
#  ['Action', 'Anime', 'Fantasy'],
#  ['Documentary', 'SpecialInterest', 'Suspense'],
#  ['Action', 'Adventure', 'Documentary'],
#  ['Animation', 'FaithandSpirituality', 'Kids'],
#  ['Animation', 'Documentary', 'Kids'],
#  ['Animation', 'Kids', 'Sports'],
#  ['Arthouse', 'Drama', 'Romance'],
#  ['Action', 'YoungAdultAudience'],
#  ['Drama', 'FaithandSpirituality', 'Kids'],
#  ['Drama', 'ScienceFiction', 'SpecialInterest'],
#  ['Action', 'Adventure', 'ScienceFiction'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'MilitaryandWar'],
#  ['Drama', 'Horror'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Western'],
#  ['Comedy', 'Drama', 'Suspense'],
#  ['Animation', 'Comedy'],
#  ['Kids', 'ScienceFiction'],
#  ['Adventure', 'Comedy', 'Kids'],
#  ['Comedy', 'Drama', 'YoungAdultAudience'],
#  ['Drama', 'LGBTQ'],
#  ['Fantasy', 'ScienceFiction'],
#  ['International', 'Unscripted'],
#  ['Arthouse', 'Comedy'],
#  ['Sports', 'Unscripted'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Documentary'],
#  ['Adventure', 'Drama', 'Suspense'],
#  ['Animation'],
#  ['Action', 'Horror', 'ScienceFiction'],
#  ['Drama', 'LGBTQ', 'Romance'],
#  ['Comedy', 'International', 'Unscripted'],
#  ['Drama', 'Kids', 'Romance'],
#  ['International', 'SpecialInterest'],
#  ['Action', 'Adventure', 'International'],
#  ['Documentary', 'MilitaryandWar', 'SpecialInterest'],
#  ['Adventure', 'Documentary', 'SpecialInterest'],
#  ['Action', 'MilitaryandWar', 'Suspense'],
#  ['Anime', 'Drama'],
#  ['Horror', 'ScienceFiction', 'Suspense'],
#  ['Adventure', 'Drama', 'FaithandSpirituality'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Kids'],
#  ['Comedy', 'Drama', 'SpecialInterest'],
#  ['Action', 'Documentary', 'SpecialInterest'],
#  ['Animation', 'Anime', 'Horror'],
#  ['Arthouse', 'SpecialInterest'],
#  ['Action', 'International', 'Suspense'],
#  ['Action', 'Sports'],
#  ['Animation', 'Anime'],
#  ['Drama', 'Historical', 'Suspense'],
#  ['TalkShowandVariety'],
#  ['Romance'],
#  ['Drama', 'Unscripted'],
#  ['Drama', 'Horror', 'SpecialInterest'],
#  ['LGBTQ', 'SpecialInterest'],
#  ['Action', 'Romance'],
#  ['LGBTQ', 'Romance'],
#  ['Horror', 'International'],
#  ['Drama', 'Fantasy', 'Suspense'],
#  ['Comedy', 'Kids', 'TalkShowandVariety'],
#  ['Romance', 'Suspense'],
#  ['Drama', 'Fantasy', 'ScienceFiction'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'International'],
#  ['Action', 'Documentary'],
#  ['Action', 'Drama', 'ScienceFiction'],
#  ['Kids', 'MusicVideosandConcerts'],
#  ['Documentary', 'Horror', 'SpecialInterest'],
#  ['Comedy', 'LGBTQ', 'Romance'],
#  ['Action', 'Comedy', 'Western'],
#  ['Comedy', 'International', 'Romance'],
#  ['Documentary', 'Suspense'],
#  ['Action', 'Arthouse', 'Drama'],
#  ['International'],
#  ['Action', 'Documentary', 'FaithandSpirituality'],
#  ['Drama', 'Kids', 'LGBTQ'],
#  ['Documentary', 'LGBTQ', 'SpecialInterest'],
#  ['Drama', 'Fantasy', 'Historical'],
#  ['Arts', 'Entertainment', 'andCulture', 'MusicVideosandConcerts'],
#  ['Action', 'Suspense', 'YoungAdultAudience'],
#  ['Action', 'Anime', 'International'],
#  ['International', 'ScienceFiction', 'Suspense'],
#  ['Action', 'Arthouse', 'Arts', 'Entertainment', 'andCulture'],
#  ['Comedy', 'LGBTQ'],
#  ['Comedy', 'International', 'SpecialInterest'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Fantasy', 'Kids', 'Suspense'],
#  ['Arthouse', 'Comedy', 'Romance'],
#  ['Comedy', 'Sports'],
#  ['Action', 'Comedy', 'Fantasy'],
#  ['Action', 'Sports', 'Suspense'],
#  ['Action', 'Animation', 'Anime'],
#  ['Anime', 'Comedy', 'International'],
#  ['Action', 'Adventure', 'Kids'],
#  ['Action', 'Comedy', 'Documentary'],
#  ['Drama', 'Fantasy', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Unscripted'],
#  ['Action', 'Animation'],
#  ['Drama', 'Horror', 'ScienceFiction'],
#  ['Drama', 'International', 'Sports'],
#  ['International', 'Sports'],
#  ['ScienceFiction', 'Suspense'],
#  ['Comedy', 'Unscripted'],
#  ['Action', 'SpecialInterest', 'Sports'],
#  ['LGBTQ', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'LGBTQ'],
#  ['Arthouse', 'Drama', 'International'],
#  ['Action', 'Suspense', 'Unscripted'],
#  ['Action', 'Comedy', 'LGBTQ'],
#  ['SpecialInterest', 'Western'],
#  ['Kids', 'Western'],
#  ['Drama', 'LGBTQ', 'Suspense'],
#  ['Comedy', 'SpecialInterest'],
#  ['Action', 'Drama', 'MilitaryandWar'],
#  ['International', 'Romance'],
#  ['Adventure', 'Drama', 'Kids'],
#  ['Documentary', 'Drama', 'Horror'],
#  ['ScienceFiction', 'Suspense', 'Unscripted'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'YoungAdultAudience'],
#  ['LGBTQ', 'SpecialInterest', 'Unscripted'],
#  ['Comedy', 'Drama', 'Fantasy'],
#  ['Fitness', 'Kids', 'SpecialInterest'],
#  ['Documentary', 'MusicVideosandConcerts', 'SpecialInterest'],
#  ['Comedy', 'Horror', 'Suspense'],
#  ['Horror', 'Suspense', 'YoungAdultAudience'],
#  ['Adventure', 'Comedy'],
#  ['Arthouse', 'Documentary'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'International'],
#  ['Drama', 'Kids', 'SpecialInterest'],
#  ['Action', 'Adventure', 'Western'],
#  ['Documentary', 'LGBTQ', 'MusicVideosandConcerts'],
#  ['Action', 'Unscripted'],
#  ['Drama', 'Horror', 'Western'],
#  ['LGBTQ'],
#  ['Comedy', 'Drama', 'ScienceFiction'],
#  ['Documentary', 'ScienceFiction', 'SpecialInterest'],
#  ['Adventure', 'Kids', 'ScienceFiction'],
#  ['Drama', 'LGBTQ', 'YoungAdultAudience'],
#  ['Action', 'Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Sports'],
#  ['Comedy', 'Fantasy', 'Kids'],
#  ['Drama', 'Horror', 'YoungAdultAudience'],
#  ['Documentary', 'Drama', 'Suspense'],
#  ['Historical', 'Horror', 'Western'],
#  ['Action', 'Arts', 'Entertainment', 'andCulture', 'Drama'],
#  ['Comedy', 'Historical'],
#  ['Fitness', 'Kids'],
#  ['Action', 'Animation', 'Fantasy'],
#  ['Arts', 'Entertainment', 'andCulture', 'International', 'Unscripted'],
#  ['Kids', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'YoungAdultAudience'],
#  ['Documentary', 'Drama', 'Kids'],
#  ['Anime', 'International', 'Kids'],
#  ['Action', 'Comedy', 'SpecialInterest'],
#  ['Action', 'Comedy', 'MilitaryandWar'],
#  ['Fantasy', 'Horror', 'ScienceFiction'],
#  ['Comedy', 'MusicVideosandConcerts'],
#  ['Arts', 'Entertainment', 'andCulture', 'Romance'],
#  ['LGBTQ', 'Romance', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary', 'LGBTQ'],
#  ['Action', 'Comedy', 'International'],
#  ['Adventure', 'International', 'Suspense'],
#  ['Action', 'Fantasy', 'Suspense'],
#  ['Animation', 'Arts', 'Entertainment', 'andCulture', 'Comedy'],
#  ['Action', 'Kids', 'Suspense'],
#  ['Action', 'Comedy', 'Kids'],
#  ['Kids', 'LGBTQ', 'Romance'],
#  ['Action', 'International', 'ScienceFiction'],
#  ['Adventure', 'Comedy', 'Fantasy'],
#  ['Animation', 'Kids', 'MusicVideosandConcerts'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'ScienceFiction'],
#  ['Adventure', 'Fantasy', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'International'],
#  ['Action', 'Kids', 'MilitaryandWar'],
#  ['Comedy', 'Horror', 'YoungAdultAudience'],
#  ['Arts',
#   'Entertainment',
#   'andCulture',
#   'MusicVideosandConcerts',
#   'SpecialInterest'],
#  ['Historical'],
#  ['Action', 'Comedy', 'ScienceFiction'],
#  ['Arts', 'Entertainment', 'andCulture', 'Horror', 'Suspense'],
#  ['Comedy', 'Sports', 'YoungAdultAudience'],
#  ['Action', 'Drama', 'FaithandSpirituality'],
#  ['Drama', 'MusicVideosandConcerts'],
#  ['Comedy', 'FaithandSpirituality', 'Kids'],
#  ['Fantasy', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Fantasy', 'Kids'],
#  ['Comedy', 'International', 'LGBTQ'],
#  ['Arts', 'Entertainment', 'andCulture', 'Fantasy', 'Horror'],
#  ['Drama', 'International', 'Kids'],
#  ['Arthouse', 'Comedy', 'Documentary'],
#  ['FaithandSpirituality', 'SpecialInterest', 'Western'],
#  ['Adventure', 'Suspense'],
#  ['Action', 'Comedy', 'Suspense'],
#  ['Anime', 'Kids', 'ScienceFiction'],
#  ['Action', 'Comedy', 'YoungAdultAudience'],
#  ['Animation', 'Suspense'],
#  ['Drama', 'Romance', 'Western'],
#  ['Adventure', 'Western'],
#  ['Horror', 'International', 'Suspense'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Animation', 'MusicVideosandConcerts'],
#  ['Comedy', 'Drama', 'FaithandSpirituality'],
#  ['Comedy', 'Kids', 'LGBTQ'],
#  ['Arts', 'Entertainment', 'andCulture', 'LGBTQ', 'Romance'],
#  ['SpecialInterest', 'Suspense'],
#  ['Horror', 'Romance', 'ScienceFiction'],
#  ['Arts', 'Entertainment', 'andCulture', 'Fantasy', 'ScienceFiction'],
#  ['Drama', 'MilitaryandWar', 'Suspense'],
#  ['Fantasy', 'Horror'],
#  ['Animation', 'ScienceFiction'],
#  ['Animation', 'Drama', 'ScienceFiction'],
#  ['FaithandSpirituality', 'MusicVideosandConcerts'],
#  ['Documentary', 'FaithandSpirituality', 'MusicVideosandConcerts'],
#  ['Arthouse', 'Drama', 'LGBTQ'],
#  ['Comedy', 'MilitaryandWar', 'Suspense'],
#  ['FaithandSpirituality', 'Kids', 'SpecialInterest'],
#  ['Kids', 'YoungAdultAudience'],
#  ['Animation', 'Drama', 'Kids'],
#  ['Animation', 'Comedy', 'Drama'],
#  ['Comedy', 'Kids', 'ScienceFiction'],
#  ['Action', 'Adventure', 'FaithandSpirituality'],
#  ['Drama', 'Suspense', 'Western'],
#  ['Arthouse', 'LGBTQ', 'Romance'],
#  ['Action', 'Adventure', 'Sports'],
#  ['Comedy', 'Drama', 'MilitaryandWar'],
#  ['Action', 'Anime'],
#  ['Comedy', 'Documentary'],
#  ['Drama', 'International', 'SpecialInterest'],
#  ['Drama', 'SpecialInterest', 'Suspense'],
#  ['Action', 'Arts', 'Entertainment', 'andCulture', 'MusicVideosandConcerts'],
#  ['Drama', 'Romance', 'SpecialInterest'],
#  ['Action', 'Documentary', 'Drama'],
#  ['Arts', 'Entertainment', 'andCulture', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'ScienceFiction'],
#  ['Arthouse', 'LGBTQ', 'Suspense'],
#  ['Drama', 'Horror', 'Romance'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'MusicVideosandConcerts'],
#  ['Action', 'Arthouse', 'Romance'],
#  ['Arts', 'Entertainment', 'andCulture', 'Kids', 'ScienceFiction'],
#  ['Arthouse', 'Documentary', 'SpecialInterest'],
#  ['Drama', 'Horror', 'International'],
#  ['Horror', 'International', 'ScienceFiction'],
#  ['Animation', 'YoungAdultAudience'],
#  ['Action', 'Anime', 'Kids'],
#  ['Drama', 'Romance', 'ScienceFiction'],
#  ['Animation', 'Romance'],
#  ['Action', 'Romance', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Suspense'],
#  ['Action', 'Adventure', 'Horror'],
#  ['Action', 'Adventure', 'SpecialInterest'],
#  ['Comedy', 'Fantasy', 'YoungAdultAudience'],
#  ['Arthouse', 'Comedy', 'LGBTQ'],
#  ['Arthouse', 'Comedy', 'SpecialInterest'],
#  ['Animation', 'Kids', 'ScienceFiction'],
#  ['Comedy', 'Horror', 'Romance'],
#  ['Animation', 'Kids', 'YoungAdultAudience'],
#  ['Comedy', 'Romance', 'YoungAdultAudience'],
#  ['International', 'LGBTQ', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'LGBTQ'],
#  ['Drama', 'SpecialInterest', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Documentary', 'International'],
#  ['Action', 'Romance', 'ScienceFiction'],
#  ['Comedy', 'Drama', 'MusicVideosandConcerts'],
#  ['Comedy', 'Drama', 'Western'],
#  ['Arthouse', 'YoungAdultAudience'],
#  ['Action', 'International', 'Romance'],
#  ['Arthouse', 'Horror', 'ScienceFiction'],
#  ['Action', 'Arts', 'Entertainment', 'andCulture'],
#  ['Arthouse'],
#  ['Arthouse', 'Comedy', 'Horror'],
#  ['Documentary', 'Kids', 'ScienceFiction'],
#  ['Drama', 'Historical', 'Romance'],
#  ['Action', 'Kids', 'YoungAdultAudience'],
#  ['Animation', 'Horror'],
#  ['Arts', 'Entertainment', 'andCulture', 'SpecialInterest', 'Unscripted'],
#  ['Horror', 'Romance', 'Western'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Horror'],
#  ['Arts', 'Entertainment', 'andCulture', 'YoungAdultAudience'],
#  ['Arthouse', 'Drama', 'Horror'],
#  ['Comedy', 'Drama', 'Horror'],
#  ['Romance', 'ScienceFiction', 'Western'],
#  ['Horror', 'Romance'],
#  ['Arthouse', 'Horror'],
#  ['Animation', 'Kids', 'Suspense'],
#  ['Horror', 'Romance', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Suspense'],
#  ['Kids', 'SpecialInterest', 'Sports'],
#  ['Action', 'Animation', 'Drama'],
#  ['Documentary', 'Horror', 'Suspense'],
#  ['Action', 'Animation', 'ScienceFiction'],
#  ['Comedy', 'Romance', 'SpecialInterest'],
#  ['Arthouse', 'Drama', 'ScienceFiction'],
#  ['Arthouse', 'Horror', 'Suspense'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'LGBTQ'],
#  ['Animation', 'SpecialInterest'],
#  ['Romance', 'Suspense', 'Western'],
#  ['Documentary', 'Drama', 'FaithandSpirituality'],
#  ['Drama', 'International', 'Western'],
#  ['Arthouse', 'Comedy', 'ScienceFiction'],
#  ['Comedy', 'Horror', 'ScienceFiction'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'Kids'],
#  ['Arts', 'Entertainment', 'andCulture', 'Comedy', 'FaithandSpirituality'],
#  ['Action', 'SpecialInterest', 'Suspense'],
#  ['Romance', 'ScienceFiction', 'Suspense'],
#  ['Documentary', 'Suspense', 'Unscripted'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture'],
#  ['Drama', 'Fantasy', 'Sports'],
#  ['Arts', 'Entertainment', 'andCulture', 'Drama', 'Horror'],
#  ['Horror', 'Western'],
#  ['Romance', 'Western'],
#  ['Adventure', 'ScienceFiction', 'Suspense'],
#  ['Arthouse', 'Comedy', 'International'],
#  ['Adventure', 'Drama', 'Fantasy'],
#  ['FaithandSpirituality', 'Kids', 'Western'],
#  ['Adventure', 'Arthouse', 'Horror'],
#  ['Comedy', 'Fantasy'],
#  ['Arthouse', 'Horror', 'Romance'],
#  ['Arthouse', 'Arts', 'Entertainment', 'andCulture', 'Horror'],
#  ['Action', 'Arts', 'Entertainment', 'andCulture', 'Suspense'],
#  ['Animation', 'Anime', 'Romance'],
#  ['MilitaryandWar'],
#  ['Arthouse', 'Drama', 'Kids'],
#  ['Action', 'Anime', 'Drama'],
#  ['Adventure', 'Comedy', 'Unscripted'],
#  ['Arthouse', 'Documentary', 'MusicVideosandConcerts'],
#  ['Action', 'Drama', 'Fantasy'],
#  ['Action', 'Arthouse', 'Horror'],
#  ['Comedy', 'Horror', 'Kids'],
#  ['Drama', 'Kids', 'Western'],
#  ['Comedy', 'Documentary', 'Drama'],
#  ['Anime', 'Drama', 'Sports'],
#  ['Arthouse', 'Romance'],
#  ['Arthouse', 'Horror', 'International'],
#  ['Drama', 'Kids', 'Suspense'],
#  ['SpecialInterest', 'TalkShowandVariety', 'Unscripted'],
#  ['Anime', 'Comedy', 'Drama']]

# %%
h=[]
for i in y:
    h+=i
print(h)
# Out:
# ['Comedy', 'Drama', 'Drama', 'International', 'Action', 'Drama', 'Suspense', 'Documentary', 'Drama', 'Fantasy', 'Fantasy', 'Kids', 'Documentary', 'SpecialInterest', 'Comedy', 'Action', 'ScienceFiction', 'Suspense', 'Drama', 'Adventure', 'Kids', 'Horror', 'Suspense', 'Documentary', 'Sports', 'Horror', 'ScienceFiction', 'Kids', 'SpecialInterest', 'Comedy', 'TalkShowandVariety', 'ScienceFiction', 'Kids', 'Action', 'Anime', 'Comedy', 'Arts', 'Entertainment', 'andCulture', 'Comedy', 'Drama', 'TVShows', 'Animation', 'Anime', 'Fantasy', 'Action', 'Adventure', 'Animation', 'Anime', 'Kids', 'MusicVideosandConcerts', 'Drama', 'Suspense', 'Fitness', 'SpecialInterest', 'FaithandSpirituality', 'SpecialInterest', 'SpecialInterest', 'Fitness', 'Action', 'MilitaryandWar', 'Western', 'Arts', 'Entertainment', 'andCulture', 'Comedy', 'TalkShowandVariety', 'Action', 'Western', 'Documentary', 'ScienceFiction', 'Adventure', 'Animation', 'Kids', 'Fantasy', 'ScienceFiction', 'Suspense', 'Suspense', 'Action', 'Documentary', 'LGBTQ', 'Drama', 'Romance', 'Suspense', 'Comedy', 'SpecialInterest', 'Unscripted', 'Unscripted', 'Documentary', 'MilitaryandWar', 'Animation', 'Kids', 'Action', 'Drama', 'Comedy', 'Documentary', 'Unscripted', 'Western', 'Action', 'Drama', 'Sports', 'Arts', 'Entertainment', 'andCulture', 'Comedy', 'Arts', 'Entertainment', 'andCulture', 'Comedy', 'SpecialInterest', 'Documentary', 'International', 'SpecialInterest', 'Comedy', 'ScienceFiction', 'Drama', 'Western', 'Arts', 'Entertainment', 'andCulture', 'Drama', 'SpecialInterest', 'Action', 'ScienceFiction', 'Documentary', 'FaithandSpirituality', 'SpecialInterest', 'Action', 'Drama', 'SpecialInterest', 'Drama', 'YoungAdultAudience', 'Drama', 'MilitaryandWar', 'Arthouse', 'Drama', 'Documentary', 'Kids', 'SpecialInterest', 'Action', 'Adventure', 'Comedy', 'Sports', 'MilitaryandWar', 'Western', 'Action', 'Comedy', 'Drama', 'Anime', 'Comedy', 'International', 'Drama', 'Romance', 'Drama', 'Horror', 'Suspense', 'Animation', 'Comedy', 'Kids', 'Action', 'Suspense', 'Arts', 'Entertainment', 'andCulture', 'Documentary', 'Documentary', 'Drama', 'Unscripted', 'Action', 'Drama', 'International', 'Drama', 'ScienceFiction', 'Suspense', 'International', 'Suspense', 'Drama', 'International', 'Suspense', 'Action', 'International', 'Anime', 'Drama', 'International', 'Action', 'Documentary', 'Sports', 'Comedy', 'Horror', 'Action', 'Adventure', 'Anime', 'Animation', 'Drama', 'SpecialInterest', 'Sports', 'Horror', 'Action', 'Comedy', 'Arthouse', 'Comedy', 'Drama', 'Arts', 'Entertainment', 'andCulture', 'Documentary', 'SpecialInterest', 'Animation', 'International', 'Kids', 'Comedy', 'Drama', 'LGBTQ', 'Action', 'Adventure', 'Comedy', 'Drama', 'Sports', 'Comedy', 'Romance', 'Documentary', 'Drama', 'Sports', 'Drama', 'International', 'Romance', 'Comedy', 'Drama', 'Romance', 'Animation', 'Anime', 'Drama', 'Action', 'Drama', 'Kids', 'Fantasy', 'Horror', 'International', 'Action', 'Animation', 'Kids', 'Drama', 'FaithandSpirituality', 'SpecialInterest', 'Action', 'Drama', 'Western', 'Action', 'Adventure', 'Suspense', 'Documentary', 'International', 'Adventure', 'Fantasy', 'Action', 'Romance', 'Western', 'Documentary', 'TalkShowandVariety', 'Documentary', 'Drama', 'LGBTQ', 'Documentary', 'Sports', 'Unscripted', 'Comedy', 'Kids', 'Arts', 'Entertainment', 'andCulture', 'Drama', 'MusicVideosandConcerts', 'SpecialInterest', 'Drama', 'FaithandSpirituality', 'Romance', 'Drama', 'FaithandSpirituality', 'LGBTQ', 'Drama', 'Suspense', 'YoungAdultAudience', 'Drama', 'LGBTQ', 'Unscripted', 'Documentary', 'MusicVideosandConcerts', 'Drama', 'FaithandSpirituality', 'SpecialInterest', 'Unscripted', 'Action', 'Fantasy', 'Action', 'Drama', 'Horror', 'International', 'MusicVideosandConcerts', 'Unscripted', 'Action', 'Kids', 'Action', 'Drama', 'Romance', 'Drama', 'Sports', 'Documentary', 'Drama', 'SpecialInterest', 'Animation', 'Comedy', 'ScienceFiction', 'Adventure', 'Drama', 'Comedy', 'Western', 'Animation', 'Kids', 'SpecialInterest ...

# %%
generosunicos=list(set(h))
print(generosunicos)
# Out:
# ['Fitness', 'andCulture', 'Animation', 'Sports', 'Documentary', 'Kids', 'Action', 'Arts', 'SpecialInterest', 'Historical', 'MilitaryandWar', 'Horror', 'TVShows', 'YoungAdultAudience', 'Suspense', 'Adventure', 'TalkShowandVariety', 'Entertainment', 'LGBTQ', 'Romance', 'Drama', 'Anime', 'MusicVideosandConcerts', 'Fantasy', 'Unscripted', 'International', 'ScienceFiction', 'Arthouse', 'FaithandSpirituality', 'Comedy', 'Western']

# %%
for i in f:
    if i in h:
        x=h.count(i)
    print(i,x)
# Out:
# Fitness 4
# andCulture 60
# Animation 41
# Sports 28
# Documentary 67
# Kids 75
# Action 108
# Arts 60
# SpecialInterest 65
# Historical 10
# MilitaryandWar 19
# Horror 60
# TVShows 1
# YoungAdultAudience 26
# Suspense 71
# Adventure 43
# TalkShowandVariety 6
# Entertainment 60
# LGBTQ 34
# Romance 53
# Drama 155
# Anime 23
# MusicVideosandConcerts 20
# Fantasy 34
# Unscripted 30
# International 52
# ScienceFiction 53
# Arthouse 41
# FaithandSpirituality 25
# Comedy 116
# Western 30

# %%
amazon.cast
# Out:
# 0          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3       Interviews with: Pink, Adele, Beyoncé, Britney...
# 4       Harry Dean Stanton, Kieran O'Brien, George Cos...
#                               ...
# 9663                             Leo Gorcey, Bobby Jordan
# 9664    DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...
# 9665    Ray Stevenson, Julian Wadham, Richard Brake, M...
# 9666    Esteban Recagno, Ezequiel Stremiz, Luciano Vit...
# 9667    Michael Caine, Emily Mortimer, Joseph Gilgun, ...
# Name: cast, Length: 9668, dtype: object

# %%
#amazon.insert(10,"durationseason",0)

# %%
amazon['durationmovie'] = [e if e>29 else 0 for i,e in enumerate(amazon['duration'])]

# %%
amazon['durationseason'] = [e if e<30 else 0 for i,e in enumerate(amazon['duration'])]

# %%
#amazon.rename(columns={'durationmovie1':'durationseason'},inplace=True)

# %%
amazon.drop(amazon.iloc[:,[15]],axis=1,inplace=True)

# %%
amazon.to_csv("amazonfinal.csv",sep=",")

# %%
amazon.head()
# Out:
#   show_id plataform   type                 title        director  \
# 0      s1    Amazon  Movie   The Grand Seduction    Don McKellar
# 1      s2    Amazon  Movie  Take Care Good Night    Girish Joshi
# 2      s3    Amazon  Movie  Secrets of Deception     Josh Webber
# 3      s4    Amazon  Movie    Pink: Staying True  Sonia Anderson
# 4      s5    Amazon  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating  duration              listed_in  \
# 0  March 30, 2021          2014    NaN       113           Comedy,Drama
# 1  March 30, 2021          2018    13+       110    Drama,International
# 2  March 30, 2021          2017    NaN        74  Action,Drama,Suspense
# 3  March 30, 2021          2014    NaN        69            Documentary
# 4  March 30, 2021          1989    NaN        45          Drama,Fantasy
#
#                                          description  durationmovie  \
# 0  A small fishing village must procure a local d...            113
# 1  A Metro Family decides to fight a Cyber Crimin...            110
# 2  After a man discovers his wife is cheating on ...             74
# 3  Pink breaks the mold once again, bringing her ...             69
# 4  Teenage Matt Banting wants to work with a famo...             45
#
#    durationseason
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
amazon.shape
# Out:
# (9668, 15)

# %%
amazon.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
pd.value_counts(amazon.dtypes)
# Out:
# object    11
# int64      1
# dtype: int64

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
disney=pd.read_csv(r"C:\Users\Pablo\Desktop\Practica\labs PI 1\PI01_DATA05\Datasets\disney_plus_titles.csv", sep=",")

# %%
disney.drop_duplicates(inplace=True)

# %%
disney.duration.replace("min","",inplace=True,regex=True)
disney.duration.replace("Season","",inplace=True,regex=True)
disney.duration.replace("Seasons","",inplace=True,regex=True)
disney.duration.replace("s","",inplace=True,regex=True)

# %%
disney.duration=disney.duration.astype(int)

# %%
disney.listed_in.replace(" ","",inplace=True,regex=True)

# %%
disney['durationmovie'] = [e if e>32 else 0 for i,e in enumerate(disney['duration'])]

# %%
disney['durationseason'] = [e if e<33 else 0 for i,e in enumerate(disney['duration'])]

# %%
disney.to_csv("disneyfinal.csv",sep=",")

# %%
cantmovie1=len(disney[(disney["type"]=="Movie")].count(axis=1))
print("La plataforma Disney tiene un total de:",cantmovie1,"peliculas")
# Out:
# La plataforma Disney tiene un total de: 1052 peliculas

# %%
disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G        23
# 1  November 26, 2021          1988     PG        91
# 2  November 26, 2021          2011   TV-G        23
# 3  November 26, 2021          2021  TV-PG        41
# 4  November 25, 2021          2021    NaN         1
#
#                      listed_in  \
# 0             Animation,Family
# 1                       Comedy
# 2      Animation,Comedy,Family
# 3                      Musical
# 4  Docuseries,Historical,Music
#
#                                          description  durationmovie  \
# 0   Join Mickey and the gang as they duck the halls!              0
# 1  Santa Claus passes his magic bag to a new St. ...             91
# 2          Sid the Sloth is on Santa's naughty list.              0
# 3               This is real life, not just fantasy!             41
# 4  A three-part documentary from Peter Jackson ca...              0
#
#    durationseason
# 0              23
# 1               0
# 2              23
# 3               0
# 4               1

# %%
disney.shape
# Out:
# (1450, 13)

# %%
disney.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country         219
# date_added        3
# release_year      0
# rating            3
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
pd.value_counts(disney.dtypes)
# Out:
# object    11
# int64      1
# dtype: int64

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 147.3+ KB

# %%
hulu=pd.read_csv(r"C:\Users\Pablo\Desktop\Practica\labs PI 1\PI01_DATA05\Datasets\hulu_titles.csv", sep=",")

# %%
hulu.drop_duplicates(inplace=True)

# %%
hulu.duration.replace("min","",inplace=True,regex=True)
hulu.duration.replace("Season","",inplace=True,regex=True)
hulu.duration.replace("Seasons","",inplace=True,regex=True)
hulu.duration.replace("s","",inplace=True,regex=True)

# %%
hulu.duration.fillna(0,inplace=True)

# %%
hulu.duration=hulu.duration.astype(int)

# %%
hulu.listed_in.replace(" ","",inplace=True,regex=True)

# %%
hulu['durationmovie'] = [e if e>34 else 0 for i,e in enumerate(hulu['duration'])]

# %%
hulu['durationseason'] = [e if e<35 else 0 for i,e in enumerate(hulu['duration'])]

# %%
hulu.to_csv("hulufinal.csv",sep=",")

# %%
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating  duration                listed_in  \
# 0  October 24, 2021          2021  TV-MA         0           Comedy,StandUp
# 1  October 23, 2021          2020    NaN        94     Crime,Drama,Thriller
# 2  October 23, 2021          2021  PG-13       108          Action,Thriller
# 3  October 22, 2021          2021      R        97                   Horror
# 4  October 22, 2021          2021    NaN       104  ScienceFiction,Thriller
#
#                                          description  durationmovie  \
# 0  ​Comedian Ricky Velez bares it all with his ho...              0
# 1  Mark, a low end South London hitman recently r...             94
# 2  A hardened Arizona rancher tries to protect an...            108
# 3  A forest ranger and two survivalists with a cu...             97
# 4  Mankind's earliest settlers on the Martian fro...            104
#
#    durationseason
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
hulu.shape
# Out:
# (3073, 13)

# %%
hulu.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# dtype: int64

# %%
pd.value_counts(hulu.dtypes)
# Out:
# object     10
# float64     1
# int64       1
# dtype: int64

# %%
hulu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 312.1+ KB

# %%
netflix=pd.read_json(r"C:\Users\Pablo\Desktop\Practica\labs PI 1\PI01_DATA05\Datasets\netflix_titles.json")

# %%
netflix.drop_duplicates(inplace=True)

# %%
netflix.duration.replace("min","",inplace=True,regex=True)
netflix.duration.replace("Season","",inplace=True,regex=True)
netflix.duration.replace("Seasons","",inplace=True,regex=True)
netflix.duration.replace("s","",inplace=True,regex=True)

# %%
netflix.duration.fillna(0,inplace=True)

# %%
netflix.duration=netflix.duration.astype(int)

# %%
netflix.listed_in.replace(" ","",inplace=True,regex=True)

# %%
netflix['durationmovie'] = [e if e>17 else 0 for i,e in enumerate(netflix['duration'])]

# %%
netflix['durationseason'] = [e if e<18 else 0 for i,e in enumerate(netflix['duration'])]

# %%
netflix.to_csv("netflixfinal.csv",sep=",")

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                                 cast        country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                               None           None
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating  duration  \
# 0  September 25, 2021          2020  PG-13        90
# 1  September 24, 2021          2021  TV-MA         2
# 2  September 24, 2021          2021  TV-MA         1
# 3  September 24, 2021          2021  TV-MA         1
# 4  September 24, 2021          2021  TV-MA         2
#
#                                            listed_in  \
# 0                                      Documentaries
# 1          InternationalTVShows,TVDramas,TVMysteries
# 2  CrimeTVShows,InternationalTVShows,TVAction&Adv...
# 3                               Docuseries,RealityTV
# 4    InternationalTVShows,RomanticTVShows,TVComedies
#
#                                          description  durationmovie  \
# 0  As her father nears the end of his life, filmm...             90
# 1  After crossing paths at a party, a Cape Town t...              0
# 2  To protect his family from a powerful drug lor...              0
# 3  Feuds, flirtations and toilet talk go down amo...              0
# 4  In a city of coaching centers known to train I...              0
#
#    durationseason
# 0               0
# 1               2
# 2               1
# 3               1
# 4               2

# %%
netflix.shape
# Out:
# (8807, 14)

# %%
netflix.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          2634
# cast               825
# country            831
# date_added          10
# release_year         0
# rating               4
# duration             0
# listed_in            0
# description          0
# durationmovie        0
# durationseason       0
# dtype: int64

# %%
pd.value_counts(netflix.dtypes)
# Out:
# object    11
# int64      1
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB
